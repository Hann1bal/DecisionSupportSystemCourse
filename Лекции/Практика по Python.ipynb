# %% [markdown]
# #Python вовсе не про змей
# Сегодня познакомимся с языком Python (Пайтон). Язык python является гибким инструменитом, так как в себе объяединяет такие качества как:
#
# 1. Легкость в освоении.
# 2. Скриптовый стиль написания кода. (Можно делать простые инструкции без углубления в классы и функции)
# 3. Поддерживает ООП.
# 4. Для него существуют множество сторонних библеотек, которые расширяют базоывй функционал.
# 5. Огромное сообщество, где можно получить помощь.
# 6. Форсится в интеренете)).
#
# Python является интерпритируемым языком.
# В отличие от компилируемых языков, интерпретируемым для исполнения программы не нужен машинный код; вместо этого программу построчно исполнят интерпретаторы. Раньше процесс интерпретации занимал очень много времени, но с приходом таких технологий, как JIT-компиляция, разрыв между компилируемыми и интерпретируемыми языками сокращается. Примерами интерпретируемых языков являются PHP, Perl, Ruby и Python. Вот некоторые из концептов, которые стали проще благодаря интерпретируемым языкам:
#
#   1. Независимость от платформы;
#   2. Рефлексия;
#   3. Динамическая типизация;
#   4. Меньший размер исполняемых файлов:
#   5. Динамические области видимости.
#
# Основным недостатком интерпретируемых языком является их невысокая скорость исполнения. Тем не менее, JIT-компиляция позволяет ускорить процесс благодаря переводу часто используемых последовательностей инструкции в машинный код.
# # Приключения Монти Пайтона в мире IT
# ![изображение.png](data:image/png;base64,...)
#
# **Утиная типизация** – это концепция, характерная для языков программирования с динамической типизацией, согласно которой конкретный тип или класс объекта не важен, а важны лишь свойства и методы, которыми этот объект обладает.
#
# 1.    Типы int и float можно конвертировать в str, потому что строка может включать не только символы алфавита, но и цифры.
# 2.    Значения типа str всегда представлены в кавычках, а для int, float и bool они не используются.
# 3.    Строку, включающую символы алфавита, не выйдет конвертировать в целое или число с плавающей точкой.

# %%
value = int("345")
print(type(value))
# Out:
# <class 'int'>

# %% [markdown]
# Переменные в Python не требуют объявления типа (так как Python – язык с динамической типизацией) и являются ссылками на область памяти. Правила именования переменных:
#
# 1.    имя переменной может состоять только из букв, цифр и знака подчёркивания;
# 2.    имя не может начинаться с цифры;
# 3.    имя не может содержать специальных символов @, $, %.
#
#
# Всё в Python - объект.
#
# Т.е. любая переменная - это ссылка на объект.
#
# Единственная возможность объявить переменную и не инициализировать её - это "someVar = None".

# %%
a = b = c = 33
print(id(a))
print(id(b))
print(id(c))
# Out:
# 94141454212608
# 94141454212608
# 94141454212608

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# # Имена переменных
#
#
# Имена переменных не должны пересекаться с названиями операторов и модулей или же других зарезервированных слов. В Python есть рекомендации по именованию функций, классов и переменных:
#
# 1.    имена переменных обычно пишутся маленькими буквами (например db_name);
# 2.    имена функций задаются маленькими буквами, с подчёркиваниями между словами (например, get_names);
# 3.    имена классов задаются словами с заглавными буквами без пробелов, это так называемый CamelCase (например, CiscoSwitch).

# %% [markdown]
# # Синтаксис Python
#
# Первое, что бросается в глаза, если говорить о синтаксисе в Python, это отступы. Отступы имеют значение:
#
# 1.    они определяют, какой код попадает в блок;
# 2.    когда блок кода начинается и заканчивается.
#
#
# Пример кода Python:

# %%
a = 10
b = 5

if a > b: 
    print("A больше B") #Тело условия
    print(a - b)
elif a==b:
  print("A equil B")
  
else:
    print("B больше или равно A")
    print(b - a)

print("Конец")

def open_file(filename):
    print("Чтение файла", filename) #Тело функции
    with open(filename) as f:
        return f.read()
        print("Готово")
# Out:
# A больше B
# 5
# Конец

# %% [markdown]
# # Комментарии или то как оставлять послание потомкам
#
# При написании кода часто нужно оставить комментарий, например, чтобы описать особенности работы кода.
#
# Комментарии в Python могут быть однострочными:

# %%
# Очень важный комментарий
a = 10
b = 5 # Очень нужный комментарий

# %% [markdown]
# Однострочные комментарии начинаются со знака решётки. Обратите внимание, что комментарий может быть как в строке, где находится сам код, так и в отдельной строке.
#
# При необходимости написать несколько строк с комментариями, чтобы не ставить перед каждой решётку, можно сделать многострочный комментарий:

# %%
"""
Очень важный
и длинный комментарий
"""
a = 10
b = 5

# %% [markdown]
# Для многострочного комментария можно использовать три двойные или три одинарные кавычки. Комментарии могут использоваться как для того, чтобы комментировать, такие строки будут пропущены.

# %% [markdown]
# # Типы данных или как ты сам себя определил
# В Python есть несколько стандартных типов данных:
#
# 1.    Number (числа)
# 2.    String (строки)
# 3.    List (списки)
# 4.    Dictionary (словари)
# 5.    Tuple (кортежи)
# 6.    Set (множества)
# 7.    Boolean (логический тип данных)
#
# Эти типы данных можно, в свою очередь, классифицировать по нескольким признакам:
#
# 1.    изменяемые (списки, словари и множества)
# 2.    неизменяемые (числа, строки и кортежи)
# 3.    упорядоченные (списки, кортежи, строки и словари)
# 4.    неупорядоченные (множества)
# 5.    составные (все виды списков)
# 6.    Несоставные(простые типы(int, str, bool...))
# 6.    Двоичные: bytes, bytearray, memoryview

# %%
string = "Hello, world!"
numb = 5
float_num = 6.1
boolean = True # 1-True 0-False

# %%
print(string)
print(string[3])
string[3] = "а"
# Out:
# Hello, world!
# l
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-53256d41a69c> in <module>()
#       1 print(string)
#       2 print(string[3])
# ----> 3 string[3] = "а"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# Упс, ошибка! Как вы видете, строка неизменна (immutable). Соответственно мы не можем изменить сам объект, а создаем новый.
# К неизменяемым типам данных относятся так же числа и кортежи.

# %%
letter_d = 'd'

a = 'Hello, World'
c = 'Hello Worl' + letter_d
d = 'Hello Worl' + 'd'

print(f"The ID of a: {id(a)}")
print(f"The ID of c: {id(c)}")
print(f"The ID of d: {id(d)}")
# Out:
# The ID of a: 140043178206512
# The ID of c: 140043178689520
# The ID of d: 140043178690672

# %%
example_list = [1,"s", 5.6, True, [1,3,4], (1,"s", 5.6, True), {1:"value", "2":2, 3:[1,"s", 5.6, True]}]
print(example_list)

"""
Пример того как работает изменяемость в типах  данных.
"""
list_1 = [1,"sda", 5.1, [1,24,4]]
print(list_1, "Исходный список")
list_1[2]=[1,2,3,4]
print(list_1, "После изменения")
# Out:
# [1, 's', 5.6, True, [1, 3, 4], (1, 's', 5.6, True), {1: 'value', '2': 2, 3: [1, 's', 5.6, True]}]
# [1, 'sda', 5.1, [1, 24, 4]] Исходный список
# [1, 'sda', [1, 2, 3, 4], [1, 24, 4]] После изменения

# %% [markdown]
# Как вы видите на примере выше тип list может содержать любой тип данных в себе и может быть изменяем. Далее расмотрим остальные составные типы.

# %%
dictionary = {"key":"value"} #Изменяемый именнованный список. Используется повсеместно когда нужно по ключу получать значение.
tuples=(1,2,3,4,5) # Неизменяемый список.
a = set() # Список который хранит в себе только уникальные значения.
a.add(1)
a.add(2)

# %% [markdown]
# #**Проверка типов**
# При преобразовании типов данных могут возникнуть ошибки такого рода:

# %%
int('a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-233884bacd4e> in <module>()
# ----> 1 int('a')
#
# ValueError: invalid literal for int() with base 10: 'a'

# %% [markdown]
# Ошибка абсолютно логичная. Мы пытаемся преобразовать в десятичный формат строку „a“.
#
# И если тут пример выглядит, возможно, глупым, тем не менее, когда нужно, например, пройтись по списку строк и преобразовать в числа те из них, которые содержат числа, можно получить такую ошибку.
#
# Чтобы избежать её, было бы хорошо иметь возможность проверить, с чем мы работаем.
#
# # **isdigit**
#
# В Python такие методы есть. Например, чтобы проверить, состоит ли строка из одних цифр, можно использовать метод **isdigit**:

# %%
 print("a".isdigit())
 print("a10".isdigit())
 print("10a".isdigit())
 print("10".isdigit())
# Out:
# False
# False
# False
# True

# %% [markdown]
# # **isalpha**
#
# Проверяет состоит ли строка только из букв.

# %%
print("a".isalpha())
print("a100".isalpha())
print("a-- ".isalpha())
print("a ".isalpha())
# Out:
# True
# False
# False
# False

# %% [markdown]
# # **isalnum**
#
# Метод isalnum позволяет проверить, состоит ли строка из букв или цифр:

# %%
print("a".isalnum())


print("a10".isalnum())
# Out:
# True
# True

# %% [markdown]
# # **type**
#
# Иногда, в зависимости от результата, библиотека или функция может выводить разные типы объектов. Например, если объект один, возвращается строка, если несколько, то возвращается кортеж.
#
# Нам же надо построить ход программы по-разному, в зависимости от того, была ли возвращена строка или кортеж.
#
# В этом может помочь функция type:
# ```python
#
# In [13]: type("string")
# Out[13]: str
#
# In [14]: type("string") == str
# Out[14]: True
# ```
#
# Аналогично с кортежем (и другими типами данных):
# ```python
#
# In [15]: type((1,2,3))
# Out[15]: tuple
#
# In [16]: type((1,2,3)) == tuple
# Out[16]: True
#
# In [17]: type((1,2,3)) == list
# Out[17]: False
# ```
#
# Соответственно мы можем это использовать, например когда итерируем полученный объект, но если на вернётся к примеру int, что приведёт к вызову исключения:
# ```python
# TypeError: 'int' object is not iterable
# ```
# И в таких случаях и возникает необходимость проверять тип объекта, когда мы не можем сказать точно, что за объект.

# %% [markdown]
# # **Контроль хода программы или как заставить компьютер делать вашу работу**
# До сих пор, весь код выполнялся последовательно - все строки скрипта выполнялись в том порядке, в котором они записаны в файле. В этом разделе рассматриваются возможности Python в управлении ходом программы:
#
# *   ответвления в ходе программы с помощью конструкции if/elif/else
# *   повторение действий в цикле с помощью конструкций for и while
# *   обработка ошибок с помощью конструкции try/except

# %% [markdown]
# # **for**
# Очень часто одно и то же действие надо выполнить для набора однотипных данных. Например, преобразовать все строки в списке в верхний регистр. Для выполнения таких действий в Python используется цикл for.
#
# Цикл for перебирает по одному элементы указанной последовательности.
#
# Примеры последовательностей элементов, по которым может проходиться цикл for:
#
# *    строка
# *    список
# *    словарь
# *    функция range
# *    любой итерируемый объект

# %%
list = [1,2,3,4,5,6]
for i in list_1:
  print(i)
# Out:
# 1
# sda
# [1, 2, 3, 4]
# [1, 24, 4]

# %% [markdown]
# # **while**
#
# Цикл while - это еще одна разновидность цикла в Python.
#
# В цикле while, как и в выражении if, надо писать условие. Если условие истинно, выполняются действия внутри блока while. При этом, в отличие от if, после выполнения кода в блоке, while возвращается в начало цикла.
#
# При использовании циклов while необходимо обращать внимание на то, будет ли достигнуто такое состояние, при котором условие цикла будет ложным.
#
# Рассмотрим простой пример:

# %%
flag = True
i=0
while flag:
  i+=1
  if i == 10:flag=False
  else:print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %% [markdown]
# # **break, continue, pass то что выводит цикл из себя**
#
# В Python есть несколько операторов, которые позволяют менять поведение циклов по умолчанию.
# Оператор break
#
# Оператор break позволяет досрочно прервать цикл:
#
# *    break прерывает текущий цикл и продолжает выполнение следующих выражений
# *    если используется несколько вложенных циклов, break прерывает внутренний цикл и продолжает выполнять выражения, следующие за блоком break может использоваться в циклах for и while

# %%
for num in range(10):
  if num < 7:
    print(num)
  else:
    break
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
#Пример с циклом while:
i = 0
while i < 10:
  if i == 5:
    break
  else:
    print(i)
    i += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # **Оператор continue**
#
#
# Оператор continue возвращает управление в начало цикла. То есть, continue позволяет «перепрыгнуть» оставшиеся выражения в цикле и перейти к следующей итерации.
#
# Пример с циклом for:

# %%
for num in range(2, 10):
  if num % 2 == 0:
    print("Found an even number", num)
    continue
  print("Found an odd number", num)
# Out:
# Found an even number 2
# Found an odd number 3
# Found an even number 4
# Found an odd number 5
# Found an even number 6
# Found an odd number 7
# Found an even number 8
# Found an odd number 9

# %% [markdown]
# # **Оператор pass**
#
# Оператор pass ничего не делает. Фактически, это такая заглушка для объектов.
#
# Например, pass может помочь в ситуации, когда нужно прописать структуру скрипта. Его можно ставить в циклах, функциях, классах. И это не будет влиять на исполнение кода.
#
# Пример использования pass:

# %%
for num in range(10):
  if num == 7:
    pass
  else:
    print(num)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 8
# 9

# %% [markdown]
# # **А что если ...**
#
# ![76617.jpg](data:image/jpeg;base64,...)
#
# Конструкция if/elif/else позволяет делать ответвления в ходе программы. Программа уходит в ветку при выполнении определенного условия.
#
# В этой конструкции только if является обязательным, elif и else опциональны:
#
# *    Проверка if всегда идет первой.
# *    После оператора if должно быть какое-то условие: если это условие выполняется (возвращает True), то действия в блоке if выполняются.
# *    С помощью elif можно сделать несколько разветвлений, то есть, проверять входящие данные на разные условия.
# *    Блок elif это тот же if, но только следующая проверка. Грубо говоря, это «а если …»
# *    Блоков elif может быть много.
# *    Блок else выполняется в том случае, если ни одно из условий if или elif не было истинным.
#
# Пример конструкции:

# %%
a = 3
if a > 4:print(True)
elif a == 3:print("This is True")
else:print(False)
# Out:
# This is True

# %% [markdown]
# # **Условия**
#
# Конструкция if построена на условиях: после if и elif всегда пишется условие. Блоки if/elif выполняются только когда условие возвращает True, поэтому первое с чем надо разобраться - это что является истинным, а что ложным в Python.
# True и False
#
# В Python, кроме очевидных значений True и False, всем остальным объектам также соответствует ложное или истинное значение:
#
# 1.   истинное значение:
#   *        любое ненулевое число
#   *        любая непустая строка
#   *        любой непустой список
# 2.    ложное значение:
#   *        0
#   *        None
#   *        пустая строка
#   *        пустой объект
#
# Например, так как пустой список это ложное значение, проверить, пустой ли список, можно таким образом:

# %%
list_to_test = [1, 2, 3]
if list_to_test:
  print("В списке есть объекты")
# Out:
# В списке есть объекты

# %% [markdown]
# # **Оператор in**
#
# Оператор in позволяет выполнять проверку на наличие элемента в последовательности (например, элемента в списке или подстроки в строке):

# %%
vlan = [10, 20, 30, 40]
if 10 in vlan:
  print(True)
# Out:
# True

# %% [markdown]
# # **Операторы and, or, not**
#
# В условиях могут также использоваться логические операторы and, or, not:

# %%
vlan = [10, 20, 30, 40]
if 10 and 20 in vlan:
  print(True)
if 10 and 50 in vlan:
  print(False)
if 10 or 20 in vlan:
  print(True)
if 10 or 50 in vlan:
  print(True)
if 60 or 50 in vlan:
  print(False)
if 60 not in vlan:
  print(True)
if 60 and 50 not in vlan:
  print(True)
# Out:
# True
# True
# True
# False
# True
# True

# %% [markdown]
# # **Тернарное выражение (Ternary expression)**
#
# Иногда удобнее использовать тернарный оператор, нежели развернутую форму:

# %%
s = [1, 2, 3, 4]
result = True if len(s) > 5 else False #Этим лучше не злоупотреблять, но в простых выражениях такая запись может быть полезной.
print(result)
# Out:
# False
